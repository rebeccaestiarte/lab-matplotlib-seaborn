# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
#METHOD 1: vertical subplots

# Creating 2 subplots, sharing x
fig, axs = plt.subplots(2, sharex='col', figsize = (5,10))
fig.suptitle('Graphs', fontsize = 20)

# defining subplot 1
axs[0].plot(x, y, "orangered", linewidth = 4)
plt.xlabel("x", fontsize = 16)
plt.ylabel("y", fontsize = 16)

# defining subplot 2
axs[1].plot(x, z, "deepskyblue", linewidth = 4)
plt.xlabel("x", fontsize = 16)
plt.ylabel("z", fontsize = 16)

plt.show() 
plt.clf()

# %%
# Usign SCA (NOTE)
fig, axs = plt.subplots(2, sharex='col', figsize = (5,10))
fig.suptitle('Graphs', fontsize = 20)

plt.sca(axs[0])
plt.plot(x, y, "orangered", linewidth = 4)
plt.xlabel("x", fontsize = 16)
plt.ylabel("y", fontsize = 16)

plt.sca(axs[1])
plt.plot(x, z, "deepskyblue", linewidth = 4)
plt.xlabel("x", fontsize = 16)
plt.ylabel("z", fontsize = 16)

plt.show() 
plt.clf()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
#METHOD 2: horizontal subplots

# Creating 2 subplots
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,5))
fig.suptitle('Graphs', fontsize = 20)

# definining subplot 1
ax1.plot(x, y, "orangered", linewidth = 4)
ax1.set_xlabel("x", fontsize = 16)
ax1.set_ylabel("y", fontsize = 16)

# definining subplot 
ax2.plot(x, z, "deepskyblue", linewidth = 4)
ax2.set_xlabel("x", fontsize = 16)
ax2.set_ylabel("z", fontsize = 16)

plt.show() 
plt.clf()

# %%
#METHOD 3: create figure 1, figure 2, and then add the plots to each.

fig_mix = plt.figure(figsize = (10,10))
sub1 = fig_mix.add_subplot(221)
sub2 = fig_mix.add_subplot(222)

sub1.plot (x,y, "orangered", linewidth = 4)
sub1.set_xlabel("x", fontsize = 16)
sub1.set_ylabel("y", fontsize = 16)

sub2.plot (x,z, "deepskyblue", linewidth = 4)
sub2.set_xlabel("x", fontsize = 16)
sub2.set_ylabel("z", fontsize = 16)

plt.show() 
plt.clf()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
#Already done previously

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# Creating 2 subplots
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,5))
fig.suptitle('Graphs 2', fontsize = 20)

# definining subplot 1
ax1.plot(x, x**2, "orangered", linewidth = 4)
ax1.set_xlabel("x", fontsize = 15)
ax1.set_ylabel("x^2", fontsize = 15)
ax1.set_xscale("linear")

# definining subplot 2
y = np.exp(x)

ax2.plot(x, y, "deepskyblue", linewidth = 4)
ax2.set_xlabel("x", fontsize = 15)
ax2.set_ylabel("e^x", fontsize = 15)
ax2.set_yscale("log")
ax2.set_xscale("log")

plt.show() 
plt.clf()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,5))
fig.suptitle('Graphs 2', fontsize = 20)

ax1.plot(x, x**2, "orangered", label = "y=x^2", linewidth = 4)
ax1.set_xlabel("x", fontsize = 15)
ax1.set_ylabel("x^2", fontsize = 15)
ax1.set_xscale("linear")
ax1.legend()

# definining subplot 2
y = np.exp(x)

ax2.plot(x, y, "deepskyblue", label = "y=e^x", linewidth = 4)
ax2.set_xlabel("x", fontsize = 15)
ax2.set_ylabel("e^x", fontsize = 15)
ax2.set_yscale("log")
ax2.set_xscale("log")
ax2.legend()

plt.show() 
plt.clf()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
from sqlalchemy import create_engine

driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'fitbit'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)

engine = create_engine(connection_string)
engine
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/fitbit
# Engine(mysql+pymysql://data-students:***@34.65.10.136/fitbit)

# %%
fitbit = pd.read_sql('SELECT * FROM fitbit2', engine)

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps_by_month = fitbit[["Months_encoded", "Steps"]].groupby("Months_encoded", as_index = False).median()
round(steps_by_month)
# Out:
#     Months_encoded    Steps
# 0                1  10366.0
# 1                2   9235.0
# 2                3  11122.0
# 3                4  13846.0
# 4                5  11998.0
# 5                6  12936.0
# 6                7  10644.0
# 7                8  12213.0
# 8                9   9343.0
# 9               10   7865.0
# 10              11   9454.0
# 11              12   8531.0

# %%
steps_by_weekday = fitbit[["Work_or_Weekend", "Steps"]].groupby("Work_or_Weekend", as_index = False).median()
round(steps_by_weekday)
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10446.0

# %%
fig, axs = plt.subplots(1,2, figsize = (12,4))
fig.suptitle('Report', fontsize = 15)

x = avg_steps_by_month["Months_encoded"]
y = avg_steps_by_month["Steps"]

plt.sca(axs[0])
plt.bar(x,y, label = "avg. steps", width= 0.6, color = "lightskyblue", )
plt.title("Steps by month", fontsize=12)
plt.xlabel("Months", fontsize = 10)
plt.ylabel("Steps", fontsize = 10)
plt.legend()
plt.xticks(np.arange(1, 13), ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug', 'Sep' , 'Oct', 'Nov', 'Dec'))


x = steps_by_weekday["Work_or_Weekend"]
y = steps_by_weekday["Steps"]

plt.sca(axs[1])
plt.bar(x,y, label = "avg. steps", width= 0.6, color = "steelblue", )
plt.title("Steps by weekday", fontsize=12)
plt.xlabel("Weekend or Weekday", fontsize = 10)
plt.ylabel("Steps", fontsize = 10)
plt.legend()
plt.xticks(np.arange(0, 2), ('Weekend', 'Weekday'))

#Saving & showing figures
plt.savefig("figures/Report1.png", dpi = 400, quality = 100) #
plt.show() 
plt.clf()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
#Solution 1
list1 = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
for i in list1:
    plt.scatter(fitbit[i], fitbit["Steps"], s = 100, color = "orangered", marker = ".")
    plt.title(f"{i} Vs. Steps")
    plt.ylabel("steps", fontsize = 10)
    plt.xlabel(f"{i}", fontsize = 10)
    plt.show()

plt.savefig("figures/Report2.1.png", dpi = 400, quality = 100) #
plt.show() 
plt.clf()

# %%
#Solution 2
fig, axs = plt.subplots(1,3, figsize = (17,5))
fig.suptitle('Report 2', fontsize = 10)

x = [steps for steps in fitbit["Steps"]]
y1 = [minutes for minutes in fitbit["Minutes Lightly Active"]]
y2 = [minutes for minutes in fitbit["Minutes Very Active"]]
y3 = [minutes for minutes in fitbit["Minutes Sedentary"]]

plt.sca(axs[0])
plt.scatter(x , y1, s = 100, color = "orangered", marker = ".")
plt.title("Minutes Lightly Active vs Steps", fontsize=10)
plt.xlabel("steps", fontsize = 6)
plt.ylabel("minutes", fontsize = 6)

plt.sca(axs[1])
plt.scatter(x , y2, s = 100, color = "steelblue", marker = "*")
plt.title("Minutes Very Active vs Steps", fontsize=10)
plt.xlabel("steps", fontsize = 6)
plt.ylabel("minutes", fontsize = 6)

plt.sca(axs[2])
plt.scatter(x , y3, s = 100, color = "lightskyblue", marker = "x")
plt.title("Minutes Not Active vs Steps", fontsize=10)
plt.xlabel("steps", fontsize = 6)
plt.ylabel("minutes", fontsize = 6)

#Saving & showing figures
plt.savefig("figures/Report2.2.png", dpi = 400, quality = 100) #
plt.show() 
plt.clf()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
from sqlalchemy import create_engine

driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'titanic'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)

engine = create_engine(connection_string)
engine

titanic = pd.read_sql('SELECT * FROM titanic', engine)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/titanic

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['float'])
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4e1243bd22c6> in <module>
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(exclude=['float'])
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use("classic") #will apply to all plots from now on
plt.rcParams["figure.figsize"] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic["Age"], 
         bins = 20,
         histtype = "bar",
         color = "Purple")
# Out:
# (array([ 51.,  21.,  25.,  53., 123., 203., 178., 169., 150.,  70.,  68.,
#          68.,  47.,  28.,  21.,  21.,   5.,   5.,   2.,   1.]),
#  array([ 0.17  ,  4.1615,  8.153 , 12.1445, 16.136 , 20.1275, 24.119 ,
#         28.1105, 32.102 , 36.0935, 40.085 , 44.0765, 48.068 , 52.0595,
#         56.051 , 60.0425, 64.034 , 68.0255, 72.017 , 76.0085, 80.    ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axs = plt.subplots(1,3, figsize = (17,5))
fig.suptitle('Report 3', fontsize = 10)

plt.sca(axs[0])
plt.hist(titanic["Age"], 
         bins = 10,
         histtype = "bar",
         color = "orangered") 

plt.sca(axs[1])
plt.hist(titanic["Age"], 
         bins = 20,
         histtype = "barstacked",
         color = "darksalmon") 

plt.sca(axs[2])
plt.hist(titanic["Age"], 
         bins = 50,
         histtype = "step",
         color = "coral")

plt.savefig("figures/Report3.png", dpi = 400, quality = 100) 
plt.show()
plt.clf()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The higher the bins, the more specific is the plot about the distribution of ages.
"""
# Out:
# '\nThe higher the bins, the more specific is the plot about the distribution of ages.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
x = [titanic["Age"]]
sns.distplot(x)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
distribution_by_gender = titanic.groupby("Gender").count()
embarked_by_gender = pd.DataFrame(distribution_by_gender["Embarked"])
embarked_by_gender =embarked_by_gender.reset_index()

# %%
percentages = (embarked_by_gender["Embarked"] / embarked_by_gender["Embarked"].sum())*100
percentages
# Out:
# 0    35.599694
# 1    64.400306
# Name: Embarked, dtype: float64

# %%
# Method 1.1 - matplotlib (histogram)

plt.figure(figsize = (17,6))
plt.pie(percentages, 
        labels = ["male", "female"],
        colors = ["orangered", "slateblue"],
        startangle = 0,
        autopct = "%1.1f%%",
       )
plt.title("Gender distribution")

plt.show()
plt.clf()

# %%
embarked_by_gender["Gender"]
# Out:
# 0    female
# 1      male
# Name: Gender, dtype: object

# %%
# Method 1.2 - matplotlib (barchart)

x = embarked_by_gender["Gender"]
y = embarked_by_gender["Embarked"]

plt.figure(figsize = (9,6))
plt.bar(x,y, width=0.9, color = ["orangered"])
plt.title("Gender distribution")
# Out:
# Text(0.5, 1.0, 'Gender distribution')

# %%
# Method 2 - seaborn
sns.set(style="whitegrid")
ax = sns.barplot(x, y , data = embarked_by_gender, palette = "Purples")

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
grouped_by_class = titanic.groupby("Pclass").count()
grouped_by_class = grouped_by_class.reset_index()
grouped_by_class
# Out:
#    Pclass  PassengerId  Survived  Name  Gender  Age  SibSp  Parch  Ticket  \
# 0       1          323       216   323     323  323    323    323     323
# 1       2          277       184   277     277  277    277    277     277
# 2       3          709       491   709     709  709    709    709     709
#
#    Fare  Cabin  Embarked
# 0   323    323       323
# 1   277    277       277
# 2   709    709       709

# %%
x = grouped_by_class["Pclass"]
y = grouped_by_class["Embarked"]

plt.figure(figsize = (9,6))
plt.bar(x,y, width=0.9, color = ["orangered"])
plt.title("Gender distribution", fontsize = 20)
plt.xlabel("class", fontsize = 14)
plt.ylabel("no of passangers", fontsize = 14)
plt.xticks(np.arange(1,4), ("Class 1", "Class 2", "Class 3"))
# Out:
# ([<matplotlib.axis.XTick at 0x133d819a0>,
# ...
#  <a list of 3 Text xticklabel objects>)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
#Matplot
plt.boxplot(titanic["Age"], patch_artist=True, meanline = True)

#SHOW DATA
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1396db730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1396dbac0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1396db490>],
#  'medians': [<matplotlib.lines.Line2D at 0x139b49490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1396db370>],
#  'means': []}

# %%
#Seaborn
sns.boxplot(titanic["Age"], orient = "v")

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Comment..
"""
# Out:
# '\nComment..\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
#Matplot

plt.violinplot(titanic["Age"])
plt.show()

# %%
#Seaborn

sns.violinplot(titanic["Age"], orient = "v")

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The distribution of the population by age.
"""
# Out:
# '\nThe distribution of the population by age.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

x = titanic ["Age"]
y = titanic ["Fare"]

fig =  plt.figure(figsize = (17,6))
plt.scatter(x , y , s = 100, color = "tan", marker = ".")
plt.title("Age vs Fare", fontsize=20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("fare", fontsize = 15)
# Out:
# Text(0, 0.5, 'fare')

# %%
# Method 2 - seaborn
dataset = titanic [["Age", "Fare"]]

fig =  plt.figure(figsize = (17,6))
ax = sns.scatterplot(x=titanic["Age"], y=titanic["Fare"], data=dataset)

# %%
"""
No correlation
"""

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,  square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
1. Fare & Passenger Class
2. Age and Passanger Class
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

x = titanic ["Pclass"]
y = titanic ["Age"]

sns.boxplot(x,y)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
x = sns.FacetGrid(titanic, col="Gender")
x.map(plt.hist, "Age")
